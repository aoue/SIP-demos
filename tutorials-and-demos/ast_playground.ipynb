# %%
"""
We want to take a look at using the AST library.
Below is a simple function that we will be examining using ASTs.
"""
import inspect
import chess
def minimax(b: chess.Board, player: bool, depth: int):

    def get_max_move(b: chess.Board, player: bool, depth: int, alpha: int, beta: int):
        # e = evaluation(b, player)['total_score']
        e = eval_material(b, player)
        if depth == 0 or abs(e) == inf:
            return e, None

        best_value = -inf
        best_moves = []
        for m in b.legal_moves:
            temp_board = b.copy()
            temp_board.push(m)
            new_value = get_min_move(temp_board, depth - 1, player, alpha, beta)[0]

            # Maintain a running max of the best move
            if new_value > best_value:
                best_value = new_value
                best_moves = [m]
            elif new_value == best_value:
                best_moves.append(m)

            # Alpha-beta pruning
            if best_value >= beta:
                break
            alpha = max(alpha, best_value)

        return best_value, random.choice(best_moves)

    def get_min_move(b: chess.Board, player: bool, depth: int, alpha: int, beta: int):
        # e = evaluation(b, player)['total_score']
        e = eval_material(b, player)
        if depth == 0 or abs(e) == inf:
            return e, None
        
        worst_value = +inf
        for m in b.legal_moves:
            temp_board = b.copy()
            temp_board.push(m)
            new_value = get_max_move(temp_board, depth - 1, player, alpha, beta)[0]

            # Maintain a running minimum
            if new_value < worst_value:
                worst_value = new_value

            # Alpha-beta pruning        
            if worst_value <= alpha:
                break
            beta = min(beta, worst_value)

        return worst_value, None

    return get_max_move(b, player, depth, -inf, +inf)

code = inspect.getsource(minimax)
print("=== code ===")
print(code)
# Out:
# === code ===
# def minimax(b: chess.Board, player: bool, depth: int):
#
#     def get_max_move(b: chess.Board, player: bool, depth: int, alpha: int, beta: int):
#         # e = evaluation(b, player)['total_score']
#         e = eval_material(b, player)
#         if depth == 0 or abs(e) == inf:
#             return e, None
#
#         best_value = -inf
#         best_moves = []
#         for m in b.legal_moves:
#             temp_board = b.copy()
#             temp_board.push(m)
#             new_value = get_min_move(temp_board, depth - 1, player, alpha, beta)[0]
#
#             # Maintain a running max of the best move
#             if new_value > best_value:
#                 best_value = new_value
#                 best_moves = [m]
#             elif new_value == best_value:
#                 best_moves.append(m)
#
#             # Alpha-beta pruning
#             if best_value >= beta:
#                 break
#             alpha = max(alpha, best_value)
#
#         return best_value, random.choice(best_moves)
#
#     def get_min_move(b: chess.Board, player: bool, depth: int, alpha: int, beta: int):
#         # e = evaluation(b, player)['total_score']
#         e = eval_material(b, player)
#         if depth == 0 or abs(e) == inf:
#             return e, None
#
#         worst_value = +inf
#         for m in b.legal_moves:
#             temp_board = b.copy()
#             temp_board.push(m)
#             new_value = get_max_move(temp_board, depth - 1, player, alpha, beta)[0]
#
#             # Maintain a running minimum
#             if new_value < worst_value:
#                 worst_value = new_value
#
#             # Alpha-beta pruning
#             if worst_value <= alpha:
#                 break
#             beta = min(beta, worst_value)
#
#         return worst_value, None
#
#     return get_max_move(b, player, depth, -inf, +inf)

# %% [markdown]
# As far as using the AST goes, some of the basic features we would want to satisfy are:
# * To be able to pass the source code above into an AST and iterate through it, node by node
# * At each node, to be able to get some meaning out of the type of node we're looking at (e.g. does this node represent a 'for loop'?)
# * Supposing we had a list of rules similar to those we created for structural explanations. Could we check to see that the rules are met in order as we proceed through the ast walk?
#
# As an end goal, try to write a program that checks for the existence of a 'for loop', a 'print statement', and a 'return statement', in that order.
#
# Some resources to get you started:
# (but by no means limit yourself to these; look for more, for ones that you understand best)
# * https://www.youtube.com/watch?v=OjPT15y2EpE
# * https://medium.com/@wshanshan/intro-to-python-ast-module-bbd22cd505f7
# * https://earthly.dev/blog/python-ast/
# * https://docs.python.org/3/library/ast.html

# %%
import ast
import pprint

tree = ast.parse(code)
# pprint.pprint(ast.dump(tree))

print("=== ast walk ===")

"""
Here we walk through the ast, going 1 node at a time.
The nodes do not correspond one-to-one with each line of code, but they are still linked in meaning.
Try to read through the printout of the walk and see how each node in the walk corresponds to an element of the given code.
(In particular, the 'lineno' or 'line number' field in the printout should be helpful for understanding the connection.)
"""
for node in ast.walk(tree):
    print(node)
    print(node.__dict__)
    # print(node._fields)
    if hasattr(node, 'body'):
        print(node.body)
    else:
        print('NO BODY')
    print("children: " + str([x for x in ast.iter_child_nodes(node)]) + "\n")

    # How could we check to see if it is a certain type of node?
    # ...

    # If we were to go further than that, suppose we had a list of rules similar to those we created for structural explanations...
    # Could we check to see that the rules are met in order as we proceed through the ast walk?
    # ...
# Out:
# === ast walk ===
# <ast.Module object at 0x10614d730>
# {'body': [<ast.FunctionDef object at 0x10614dd90>], 'type_ignores': []}
# [<ast.FunctionDef object at 0x10614dd90>]
# children: [<ast.FunctionDef object at 0x10614dd90>]
#
# <ast.FunctionDef object at 0x10614dd90>
# {'name': 'minimax', 'args': <ast.arguments object at 0x10614d670>, 'body': [<ast.FunctionDef object at 0x105b6dfa0>, <ast.FunctionDef object at 0x105fd1280>, <ast.Return object at 0x105fdf5b0>], 'decorator_list': [], 'returns': None, 'type_comment': None, 'lineno': 1, 'col_offset': 0, 'end_lineno': 53, 'end_col_offset': 53}
# [<ast.FunctionDef object at 0x105b6dfa0>, <ast.FunctionDef object at 0x105fd1280>, <ast.Return object at 0x105fdf5b0>]
# children: [<ast.arguments object at 0x10614d670>, <ast.FunctionDef object at 0x105b6dfa0>, <ast.FunctionDef object at 0x105fd1280>, <ast.Return object at 0x105fdf5b0>]
#
# <ast.arguments object at 0x10614d670>
# {'posonlyargs': [], 'args': [<ast.arg object at 0x10614d790>, <ast.arg object at 0x105b6de20>, <ast.arg object at 0x105b6deb0>], 'vararg': None, 'kwonlyargs': [], 'kw_defaults': [], 'kwarg': None, 'defaults': []}
# NO BODY
# children: [<ast.arg object at 0x10614d790>, <ast.arg object at 0x105b6de20>, <ast.arg object at 0x105b6deb0>]
#
# <ast.FunctionDef object at 0x105b6dfa0>
# {'name': 'get_max_move', 'args': <ast.arguments object at 0x105b6df40>, 'body': [<ast.Assign object at 0x105b698e0>, <ast.If object at 0x105b71d30>, <ast.Assign object at 0x105b71a60>, <ast.Assign object at 0x105b716a0>, <ast.For object at 0x105b71400>, <ast.Return object at 0x105fd1820>], 'decorator_list': [], 'returns': None, 'type_comment': None, 'lineno': 3, 'col_offset': 4, 'end_lineno': 28, 'end_col_offset': 52}
# [<ast.Assign object at 0x105b698e0>, <ast.If object at 0x105b71d30>, <ast.Assign object at 0x105b71a60>, <ast.Assign object at 0x105b716a0>, <ast.For object at 0x105b71400>, <ast.Return object at 0x105fd1820>]
# children: [<ast.arguments object at 0x105b6df40>, <ast.Assign object at 0x105b698e0>, <ast.If object at 0x105b71d30>, <ast.Assign object at 0x105b71a60>, <ast.Assign object at 0x105b716a0>, <ast.For object at 0x105b71400>, <ast.Return object at 0x105fd1820>]
#
# <ast.FunctionDef object at 0x105fd1280>
# {'name': 'get_min_move', 'args': <ast.arguments object at 0x105fd1d90>, 'body': [<ast.Assign object at 0x105fd1e80>, <ast.If object at 0x105fd16d0>, <ast.Assign object at 0x105b7a760>, <ast.For object at 0x105b7afa0>, <ast.Return object at 0x105fdf5e0>], 'decorator_list': [], 'returns': None, 'type_comment': None, 'lineno': 30, 'col_offset': 4, 'end_lineno': 51, 'end_col_offset': 32}
# [<ast.Assign object at 0x105fd1e80>, <ast.If object at 0x105fd16d0>, <ast.Assign object at 0x105b7a760>, <ast.For object at 0x105b7afa0>, <ast.Return object at 0x105fdf5e0>]
# children: [<ast.arguments object at 0x105fd1d90>, <ast.Assign object at 0x105fd1e80>, <ast.If object at 0x105fd16d0>, <ast.Assign object at 0x105b7a760>, <ast.For object at 0x105b7afa0>, <ast.Return object at 0x105fdf5e0>]
#
# <ast.Return object at 0x105fdf5b0>
# {'value': <ast.Call object at 0x105fdfb20>, 'lineno': 53, 'col_offset': 4, 'end_lineno': 53, 'end_col_offset': 53}
# NO BODY
# children: [<ast.Call object at 0x105fdfb20>]
#
# <ast.arg object at 0x10614d790>
# {'arg': 'b', 'annotation': <ast.Attribute object at 0x10614df70>, 'type_comment': None, 'lineno': 1, 'col_offset': 12, 'end_lineno': 1, 'end_col_offset': 26}
# NO BODY
# children: [<ast.Attribute object at 0x10614df70>]
#
# <ast.arg object at 0x105b6de20>
# {'arg': 'player', 'annotation': <ast.Name object at 0x105b6dd00>, 'type_comment': None, 'lineno': 1, 'col_offset': 28, 'end_lineno': 1, 'end_col_offset': 40}
# NO BODY
# children: [<ast.Name object at 0x105b6dd00>]
#
# <ast.arg object at 0x105b6deb0>
# {'arg': 'depth', 'annotation': <ast.Name object at 0x105b6dc70>, 'type_comment': None, 'lineno': 1, 'col_offset': 42, 'end_lineno': 1, 'end_col_offset': 52}
# NO BODY
# children: [<ast.Name object at 0x105b6dc70>]
#
# <ast.arguments object at 0x105b6df40>
# {'posonlyargs': [], 'args': [<ast.arg object at 0x105b6ddc0>, <ast.arg object at 0x105b6dd30>, <ast.arg object at 0x105cc88b0>, <ast.arg object at 0x105b69a00>, <ast.arg object at 0x105b69040>], 'vararg': None, 'kwonlyargs': [], 'kw_defaults': [], 'kwarg': None, 'defaults': []}
# NO BODY
# children: [<ast.arg object at 0x105b6ddc0>, <ast.arg object at 0x105b6dd30>, <ast.arg object at 0x105cc88b0>, <ast.arg object at 0x105b69a00>, <ast.arg object at 0x105b69040>]
#
# <ast.Assign object at 0x105b698e0>
# {'targets': [<ast.Name object at 0x105b69730>], 'value': <ast.Call object at 0x105b697f0>, 'type_comment': None, 'lineno': 5, 'col_offset': 8, 'end_lineno': 5, 'end_col_offset': 36}
# NO BODY
# children: [<ast.Name object at 0x105b69730>, <ast.Call object at 0x105b697f0>]
#
# <ast.If object at 0x105b71d30>
# {'test': <ast.BoolOp object at 0x105b71460>, 'body': [<ast.Return object at 0x105b719d0>], 'orelse': [], 'lineno': 6, 'col_offset': 8, 'end_lineno': 7, 'end_col_offset': 26}
# [<ast.Return object at 0x105b719d0>]
# children: [<ast.BoolOp object at 0x105b71460>, <ast.Return object at 0x105b719d0>]
#
# <ast.Assign object at 0x105b71a60>
# {'targets': [<ast.Name object at 0x105b71c70>], 'value': <ast.UnaryOp object at 0x105b71cd0>, 'type_comment': None, 'lineno': 9, 'col_offset': 8, 'end_lineno': 9, 'end_col_offset': 25}
# NO BODY
# children: [<ast.Name object at 0x105b71c70>, <ast.UnaryOp object at 0x105b71cd0>]
#
# <ast.Assign object at 0x105b716a0>
# {'targets': [<ast.Name object at 0x105b71700>], 'value': <ast.List object at 0x105b71430>, 'type_comment': None, 'lineno': 10, 'col_offset': 8, 'end_lineno': 10, 'end_col_offset': 23}
# NO BODY
# children: [<ast.Name object at 0x105b71700>, <ast.List object at 0x105b71430>]
#
# <ast.For object at 0x105b71400>
# {'target': <ast.Name object at 0x105b6b730>, 'iter': <ast.Attribute object at 0x105b6bd30>, 'body': [<ast.Assign object at 0x105b6b970>, <ast.Expr object at 0x105b6bc70>, <ast.Assign object at 0x105fdcfa0>, <ast.If object at 0x105fdc8b0>, <ast.If object at 0x105fd1d00>, <ast.Assign object at 0x105fd1670>], 'orelse': [], 'type_comment': None, 'lineno': 11, 'col_offset': 8, 'end_lineno': 26, 'end_col_offset': 42}
# [<ast.Assign object at 0x105b6b970>, <ast.Expr object at 0x105b6bc70>, <ast.Assign object at 0x105fdcfa0>, <ast.If object at 0x105fdc8b0>, <ast.If object at 0x105fd1d00>, <ast.Assign object at 0x105fd1670>]
# children: [<ast.Name object at 0x105b6b730>, <ast.Attribute object at 0x105b6bd30>, <ast.Assign object at 0x105b6b970>, <ast.Expr object at 0x105b6bc70>, <ast.Assign object at 0x105fdcfa0>, <ast.If object at 0x105fdc8b0>, <ast.If object at 0x105fd1d00>, <ast.Assign object at 0x105fd1670>]
#
# <ast.Return object at 0x105fd1820>
# {'value': <ast.Tuple object at 0x105fd1700>, 'lineno': 28, 'col_offset': 8, 'end_lineno': 28, 'end_col_offset': 52}
# NO BODY
# children: [<ast.Tuple object at 0x105fd1700>]
#
# <ast.arguments object at 0x105fd1d90>
# {'posonlyargs': [], 'args': [<ast.arg object at 0x105fd15e0>, <ast.arg object at 0x105fd1550>, <ast.arg object at 0x105fd1880>, <ast.arg object at 0x105fd13a0>, <ast.arg object at 0x105fd1ac0>], 'vararg': None, 'kwonlyargs': [], 'kw_defaults': [], 'kwarg': None, 'defaults': []}
# NO BODY
# children: [<ast.arg object at 0x105fd15e0>, <ast.arg object at 0x105fd1550>, <ast.arg object at 0x105fd1880>, <ast.arg object at 0x105fd13a0>, <ast.arg object at 0x105fd1ac0>]
#
# <ast.Assign object at 0x105fd1e80>
# {'targets': [<ast.Name object at 0x105fd1940>], 'value': <ast.Call object at 0x105fd1eb0>, 'type_comment': None, 'lineno': 32, 'col_offset': 8, 'end_lineno': 32, 'end_col_offset': 36}
# NO BODY
# children: [<ast.Name object at 0x105fd1940>, <ast.Call object at 0x105fd1eb0>]
#
# <ast.If object at 0x105fd16d0>
# {'test': <ast.BoolOp object at 0x105fd1430>, 'body': [<ast.Return object at 0x105b7ad30>], 'orelse': [], 'lineno': 33, 'col_offset': 8, 'end_lineno': 34, 'end_col_offset': 26}
# [<ast.Return object at 0x105b7ad30>]
# children: [<ast.BoolOp object at 0x105fd1430>, <ast.Return object at 0x105b7ad30>]
#
# <ast.Assign object at 0x105b7a760>
# {'targets': [<ast.Name object at 0x105b7af10>], 'value': <ast.UnaryOp object at 0x105b7ac40>, 'type_comment': None, 'lineno': 36, 'col_offset': 8, 'end_lineno': 36, 'end_col_offset': 26}
# NO BODY
# children: [<ast.Name object at 0x105b7af10>, <ast.UnaryOp object at 0x105b7ac40>]
#
# <ast.For object at 0x105b7afa0>
# {'target': <ast.Name object at 0x105b6e0a0>, 'iter': <ast.Attribute object at 0x105b6e220>, 'body': [<ast.Assign object at 0x105b6e280>, <ast.Expr object at 0x105b910d0>, <ast.Assign object at 0x105b91070>, <ast.If object at 0x105fdf0a0>, <ast.If object at 0x105fdffd0>, <ast.Assign object at 0x105fdfe20>], 'orelse': [], 'type_comment': None, 'lineno': 37, 'col_offset': 8, 'end_lineno': 49, 'end_col_offset': 41}
# [<ast.Assign object at 0x105b6e280>, <ast.Expr object at 0x105b910d0>, <ast.Assign object at 0x105b91070>, <ast.If object at 0x105fdf0a0>, <ast.If object at 0x105fdffd0>, <ast.Assign object at 0x105fdfe20>]
# children: [<ast.Name object at 0x105b6e0a0>, <ast.Attribute object at 0x105b6e220>, <ast.Assign object at 0x105b6e280>, <ast.Expr object at 0x105b910d0>, <ast.Assign object at 0x105b91070>, <ast.If object at 0x105fdf0a0>, <ast.If object at 0x105fdffd0>, <ast.Assign object at 0x105fdfe20>]
#
# <ast.Return object at 0x105fdf5e0>
# {'value': <ast.Tuple object at 0x105fdffa0>, 'lineno': 51, 'col_offset': 8, 'end_lineno': 51, 'end_col_offset': 32}
# NO BODY
# children: [<ast.Tuple object at 0x105fdffa0>]
#
# <ast.Call object at 0x105fdfb20>
# {'func': <ast.Name object at 0x105fdfdf0>, 'args': [<ast.Name object at 0x105fdf2b0>, <ast.Name object at 0x105fdfc40>, <ast.Name object at 0x105fdf220>, <ast.UnaryOp object at 0x105fdf6a0>, <ast.UnaryOp object at 0x105fdf6d0>], 'keywords': [], 'lineno': 53, 'col_offset': 11, 'end_lineno': 53, 'end_col_offset': 53}
# NO BODY
# children: [<ast.Name object at 0x105fdfdf0>, <ast.Name object at 0x105fdf2b0>, <ast.Name object at 0x105fdfc40>, <ast.Name object at 0x105fdf220>, <ast.UnaryOp object at 0x105fdf6a0>, <ast.UnaryOp object at 0x105fdf6d0>]
#
# <ast.Attribute object at 0x10614df70>
# {'value': <ast.Name object at 0x10614d250>, 'attr': 'Board', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 1, 'col_offset': 15, 'end_lineno': 1, 'end_col_offset': 26}
# NO BODY
# children: [<ast.Name object at 0x10614d250>, <ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105b6dd00>
# {'id': 'bool', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 1, 'col_offset': 36, 'end_lineno': 1, 'end_col_offset': 40}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105b6dc70>
# {'id': 'int', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 1, 'col_offset': 49, 'end_lineno': 1, 'end_col_offset': 52}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.arg object at 0x105b6ddc0>
# {'arg': 'b', 'annotation': <ast.Attribute object at 0x105b6d070>, 'type_comment': None, 'lineno': 3, 'col_offset': 21, 'end_lineno': 3, 'end_col_offset': 35}
# NO BODY
# children: [<ast.Attribute object at 0x105b6d070>]
#
# <ast.arg object at 0x105b6dd30>
# {'arg': 'player', 'annotation': <ast.Name object at 0x1059ea610>, 'type_comment': None, 'lineno': 3, 'col_offset': 37, 'end_lineno': 3, 'end_col_offset': 49}
# NO BODY
# children: [<ast.Name object at 0x1059ea610>]
#
# <ast.arg object at 0x105cc88b0>
# {'arg': 'depth', 'annotation': <ast.Name object at 0x105cc83a0>, 'type_comment': None, 'lineno': 3, 'col_offset': 51, 'end_lineno': 3, 'end_col_offset': 61}
# NO BODY
# children: [<ast.Name object at 0x105cc83a0>]
#
# <ast.arg object at 0x105b69a00>
# {'arg': 'alpha', 'annotation': <ast.Name object at 0x105b698b0>, 'type_comment': None, 'lineno': 3, 'col_offset': 63, 'end_lineno': 3, 'end_col_offset': 73}
# NO BODY
# children: [<ast.Name object at 0x105b698b0>]
#
# <ast.arg object at 0x105b69040>
# {'arg': 'beta', 'annotation': <ast.Name object at 0x105b699d0>, 'type_comment': None, 'lineno': 3, 'col_offset': 75, 'end_lineno': 3, 'end_col_offset': 84}
# NO BODY
# children: [<ast.Name object at 0x105b699d0>]
#
# <ast.Name object at 0x105b69730>
# {'id': 'e', 'ctx': <ast.Store object at 0x10347f6a0>, 'lineno': 5, 'col_offset': 8, 'end_lineno': 5, 'end_col_offset': 9}
# NO BODY
# children: [<ast.Store object at 0x10347f6a0>]
#
# <ast.Call object at 0x105b697f0>
# {'func': <ast.Name object at 0x105b69790>, 'args': [<ast.Name object at 0x105b715b0>, <ast.Name object at 0x105b71520>], 'keywords': [], 'lineno': 5, 'col_offset': 12, 'end_lineno': 5, 'end_col_offset': 36}
# NO BODY
# children: [<ast.Name object at 0x105b69790>, <ast.Name object at 0x105b715b0>, <ast.Name object at 0x105b71520>]
#
# <ast.BoolOp object at 0x105b71460>
# {'op': <ast.Or object at 0x10347f7f0>, 'values': [<ast.Compare object at 0x105b718b0>, <ast.Compare object at 0x105b71d00>], 'lineno': 6, 'col_offset': 11, 'end_lineno': 6, 'end_col_offset': 38}
# NO BODY
# children: [<ast.Or object at 0x10347f7f0>, <ast.Compare object at 0x105b718b0>, <ast.Compare object at 0x105b71d00>]
#
# <ast.Return object at 0x105b719d0>
# {'value': <ast.Tuple object at 0x105b71910>, 'lineno': 7, 'col_offset': 12, 'end_lineno': 7, 'end_col_offset': 26}
# NO BODY
# children: [<ast.Tuple object at 0x105b71910>]
#
# <ast.Name object at 0x105b71c70>
# {'id': 'best_value', 'ctx': <ast.Store object at 0x10347f6a0>, 'lineno': 9, 'col_offset': 8, 'end_lineno': 9, 'end_col_offset': 18}
# NO BODY
# children: [<ast.Store object at 0x10347f6a0>]
#
# <ast.UnaryOp object at 0x105b71cd0>
# {'op': <ast.USub object at 0x10347fee0>, 'operand': <ast.Name object at 0x105b71790>, 'lineno': 9, 'col_offset': 21, 'end_lineno': 9, 'end_col_offset': 25}
# NO BODY
# children: [<ast.USub object at 0x10347fee0>, <ast.Name object at 0x105b71790>]
#
# <ast.Name object at 0x105b71700>
# {'id': 'best_moves', 'ctx': <ast.Store object at 0x10347f6a0>, 'lineno': 10, 'col_offset': 8, 'end_lineno': 10, 'end_col_offset': 18}
# NO BODY
# children: [<ast.Store object at 0x10347f6a0>]
#
# <ast.List object at 0x105b71430>
# {'elts': [], 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 10, 'col_offset': 21, 'end_lineno': 10, 'end_col_offset': 23}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105b6b730>
# {'id': 'm', 'ctx': <ast.Store object at 0x10347f6a0>, 'lineno': 11, 'col_offset': 12, 'end_lineno': 11, 'end_col_offset': 13}
# NO BODY
# children: [<ast.Store object at 0x10347f6a0>]
#
# <ast.Attribute object at 0x105b6bd30>
# {'value': <ast.Name object at 0x105b6bb20>, 'attr': 'legal_moves', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 11, 'col_offset': 17, 'end_lineno': 11, 'end_col_offset': 30}
# NO BODY
# children: [<ast.Name object at 0x105b6bb20>, <ast.Load object at 0x10347f640>]
#
# <ast.Assign object at 0x105b6b970>
# {'targets': [<ast.Name object at 0x105b6b880>], 'value': <ast.Call object at 0x105b6bdc0>, 'type_comment': None, 'lineno': 12, 'col_offset': 12, 'end_lineno': 12, 'end_col_offset': 33}
# NO BODY
# children: [<ast.Name object at 0x105b6b880>, <ast.Call object at 0x105b6bdc0>]
#
# <ast.Expr object at 0x105b6bc70>
# {'value': <ast.Call object at 0x105b6bf40>, 'lineno': 13, 'col_offset': 12, 'end_lineno': 13, 'end_col_offset': 30}
# NO BODY
# children: [<ast.Call object at 0x105b6bf40>]
#
# <ast.Assign object at 0x105fdcfa0>
# {'targets': [<ast.Name object at 0x105fdc280>], 'value': <ast.Subscript object at 0x105fdcb50>, 'type_comment': None, 'lineno': 14, 'col_offset': 12, 'end_lineno': 14, 'end_col_offset': 83}
# NO BODY
# children: [<ast.Name object at 0x105fdc280>, <ast.Subscript object at 0x105fdcb50>]
#
# <ast.If object at 0x105fdc8b0>
# {'test': <ast.Compare object at 0x105fdcf70>, 'body': [<ast.Assign object at 0x105fdc670>, <ast.Assign object at 0x105fd18b0>], 'orelse': [<ast.If object at 0x105fd1760>], 'lineno': 17, 'col_offset': 12, 'end_lineno': 21, 'end_col_offset': 36}
# [<ast.Assign object at 0x105fdc670>, <ast.Assign object at 0x105fd18b0>]
# children: [<ast.Compare object at 0x105fdcf70>, <ast.Assign object at 0x105fdc670>, <ast.Assign object at 0x105fd18b0>, <ast.If object at 0x105fd1760>]
#
# <ast.If object at 0x105fd1d00>
# {'test': <ast.Compare object at 0x105fd1640>, 'body': [<ast.Break object at 0x105fd1dc0>], 'orelse': [], 'lineno': 24, 'col_offset': 12, 'end_lineno': 25, 'end_col_offset': 21}
# [<ast.Break object at 0x105fd1dc0>]
# children: [<ast.Compare object at 0x105fd1640>, <ast.Break object at 0x105fd1dc0>]
#
# <ast.Assign object at 0x105fd1670>
# {'targets': [<ast.Name object at 0x105fd1580>], 'value': <ast.Call object at 0x105fd1ee0>, 'type_comment': None, 'lineno': 26, 'col_offset': 12, 'end_lineno': 26, 'end_col_offset': 42}
# NO BODY
# children: [<ast.Name object at 0x105fd1580>, <ast.Call object at 0x105fd1ee0>]
#
# <ast.Tuple object at 0x105fd1700>
# {'elts': [<ast.Name object at 0x105fd1e20>, <ast.Call object at 0x105fd11c0>], 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 28, 'col_offset': 15, 'end_lineno': 28, 'end_col_offset': 52}
# NO BODY
# children: [<ast.Name object at 0x105fd1e20>, <ast.Call object at 0x105fd11c0>, <ast.Load object at 0x10347f640>]
#
# <ast.arg object at 0x105fd15e0>
# {'arg': 'b', 'annotation': <ast.Attribute object at 0x105fd15b0>, 'type_comment': None, 'lineno': 30, 'col_offset': 21, 'end_lineno': 30, 'end_col_offset': 35}
# NO BODY
# children: [<ast.Attribute object at 0x105fd15b0>]
#
# <ast.arg object at 0x105fd1550>
# {'arg': 'player', 'annotation': <ast.Name object at 0x105fd1b50>, 'type_comment': None, 'lineno': 30, 'col_offset': 37, 'end_lineno': 30, 'end_col_offset': 49}
# NO BODY
# children: [<ast.Name object at 0x105fd1b50>]
#
# <ast.arg object at 0x105fd1880>
# {'arg': 'depth', 'annotation': <ast.Name object at 0x105fd1910>, 'type_comment': None, 'lineno': 30, 'col_offset': 51, 'end_lineno': 30, 'end_col_offset': 61}
# NO BODY
# children: [<ast.Name object at 0x105fd1910>]
#
# <ast.arg object at 0x105fd13a0>
# {'arg': 'alpha', 'annotation': <ast.Name object at 0x105fd1b20>, 'type_comment': None, 'lineno': 30, 'col_offset': 63, 'end_lineno': 30, 'end_col_offset': 73}
# NO BODY
# children: [<ast.Name object at 0x105fd1b20>]
#
# <ast.arg object at 0x105fd1ac0>
# {'arg': 'beta', 'annotation': <ast.Name object at 0x105fd10a0>, 'type_comment': None, 'lineno': 30, 'col_offset': 75, 'end_lineno': 30, 'end_col_offset': 84}
# NO BODY
# children: [<ast.Name object at 0x105fd10a0>]
#
# <ast.Name object at 0x105fd1940>
# {'id': 'e', 'ctx': <ast.Store object at 0x10347f6a0>, 'lineno': 32, 'col_offset': 8, 'end_lineno': 32, 'end_col_offset': 9}
# NO BODY
# children: [<ast.Store object at 0x10347f6a0>]
#
# <ast.Call object at 0x105fd1eb0>
# {'func': <ast.Name object at 0x105fd19d0>, 'args': [<ast.Name object at 0x105fd1af0>, <ast.Name object at 0x105fd1c10>], 'keywords': [], 'lineno': 32, 'col_offset': 12, 'end_lineno': 32, 'end_col_offset': 36}
# NO BODY
# children: [<ast.Name object at 0x105fd19d0>, <ast.Name object at 0x105fd1af0>, <ast.Name object at 0x105fd1c10>]
#
# <ast.BoolOp object at 0x105fd1430>
# {'op': <ast.Or object at 0x10347f7f0>, 'values': [<ast.Compare object at 0x105fd1c70>, <ast.Compare object at 0x105fd1f10>], 'lineno': 33, 'col_offset': 11, 'end_lineno': 33, 'end_col_offset': 38}
# NO BODY
# children: [<ast.Or object at 0x10347f7f0>, <ast.Compare object at 0x105fd1c70>, <ast.Compare object at 0x105fd1f10>]
#
# <ast.Return object at 0x105b7ad30>
# {'value': <ast.Tuple object at 0x105b7a460>, 'lineno': 34, 'col_offset': 12, 'end_lineno': 34, 'end_col_offset': 26}
# NO BODY
# children: [<ast.Tuple object at 0x105b7a460>]
#
# <ast.Name object at 0x105b7af10>
# {'id': 'worst_value', 'ctx': <ast.Store object at 0x10347f6a0>, 'lineno': 36, 'col_offset': 8, 'end_lineno': 36, 'end_col_offset': 19}
# NO BODY
# children: [<ast.Store object at 0x10347f6a0>]
#
# <ast.UnaryOp object at 0x105b7ac40>
# {'op': <ast.UAdd object at 0x10347fe80>, 'operand': <ast.Name object at 0x105b7acd0>, 'lineno': 36, 'col_offset': 22, 'end_lineno': 36, 'end_col_offset': 26}
# NO BODY
# children: [<ast.UAdd object at 0x10347fe80>, <ast.Name object at 0x105b7acd0>]
#
# <ast.Name object at 0x105b6e0a0>
# {'id': 'm', 'ctx': <ast.Store object at 0x10347f6a0>, 'lineno': 37, 'col_offset': 12, 'end_lineno': 37, 'end_col_offset': 13}
# NO BODY
# children: [<ast.Store object at 0x10347f6a0>]
#
# <ast.Attribute object at 0x105b6e220>
# {'value': <ast.Name object at 0x105b6e100>, 'attr': 'legal_moves', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 37, 'col_offset': 17, 'end_lineno': 37, 'end_col_offset': 30}
# NO BODY
# children: [<ast.Name object at 0x105b6e100>, <ast.Load object at 0x10347f640>]
#
# <ast.Assign object at 0x105b6e280>
# {'targets': [<ast.Name object at 0x105b6e2b0>], 'value': <ast.Call object at 0x105b91310>, 'type_comment': None, 'lineno': 38, 'col_offset': 12, 'end_lineno': 38, 'end_col_offset': 33}
# NO BODY
# children: [<ast.Name object at 0x105b6e2b0>, <ast.Call object at 0x105b91310>]
#
# <ast.Expr object at 0x105b910d0>
# {'value': <ast.Call object at 0x105b91400>, 'lineno': 39, 'col_offset': 12, 'end_lineno': 39, 'end_col_offset': 30}
# NO BODY
# children: [<ast.Call object at 0x105b91400>]
#
# <ast.Assign object at 0x105b91070>
# {'targets': [<ast.Name object at 0x105b91670>], 'value': <ast.Subscript object at 0x105b913a0>, 'type_comment': None, 'lineno': 40, 'col_offset': 12, 'end_lineno': 40, 'end_col_offset': 83}
# NO BODY
# children: [<ast.Name object at 0x105b91670>, <ast.Subscript object at 0x105b913a0>]
#
# <ast.If object at 0x105fdf0a0>
# {'test': <ast.Compare object at 0x105fdfe80>, 'body': [<ast.Assign object at 0x105fdf9a0>], 'orelse': [], 'lineno': 43, 'col_offset': 12, 'end_lineno': 44, 'end_col_offset': 39}
# [<ast.Assign object at 0x105fdf9a0>]
# children: [<ast.Compare object at 0x105fdfe80>, <ast.Assign object at 0x105fdf9a0>]
#
# <ast.If object at 0x105fdffd0>
# {'test': <ast.Compare object at 0x105fdf100>, 'body': [<ast.Break object at 0x105fdfaf0>], 'orelse': [], 'lineno': 47, 'col_offset': 12, 'end_lineno': 48, 'end_col_offset': 21}
# [<ast.Break object at 0x105fdfaf0>]
# children: [<ast.Compare object at 0x105fdf100>, <ast.Break object at 0x105fdfaf0>]
#
# <ast.Assign object at 0x105fdfe20>
# {'targets': [<ast.Name object at 0x105fdf580>], 'value': <ast.Call object at 0x105fdf640>, 'type_comment': None, 'lineno': 49, 'col_offset': 12, 'end_lineno': 49, 'end_col_offset': 41}
# NO BODY
# children: [<ast.Name object at 0x105fdf580>, <ast.Call object at 0x105fdf640>]
#
# <ast.Tuple object at 0x105fdffa0>
# {'elts': [<ast.Name object at 0x105fdff70>, <ast.Constant object at 0x105fdf610>], 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 51, 'col_offset': 15, 'end_lineno': 51, 'end_col_offset': 32}
# NO BODY
# children: [<ast.Name object at 0x105fdff70>, <ast.Constant object at 0x105fdf610>, <ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fdfdf0>
# {'id': 'get_max_move', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 53, 'col_offset': 11, 'end_lineno': 53, 'end_col_offset': 23}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fdf2b0>
# {'id': 'b', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 53, 'col_offset': 24, 'end_lineno': 53, 'end_col_offset': 25}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fdfc40>
# {'id': 'player', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 53, 'col_offset': 27, 'end_lineno': 53, 'end_col_offset': 33}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fdf220>
# {'id': 'depth', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 53, 'col_offset': 35, 'end_lineno': 53, 'end_col_offset': 40}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.UnaryOp object at 0x105fdf6a0>
# {'op': <ast.USub object at 0x10347fee0>, 'operand': <ast.Name object at 0x105fdf8b0>, 'lineno': 53, 'col_offset': 42, 'end_lineno': 53, 'end_col_offset': 46}
# NO BODY
# children: [<ast.USub object at 0x10347fee0>, <ast.Name object at 0x105fdf8b0>]
#
# <ast.UnaryOp object at 0x105fdf6d0>
# {'op': <ast.UAdd object at 0x10347fe80>, 'operand': <ast.Name object at 0x105fdf310>, 'lineno': 53, 'col_offset': 48, 'end_lineno': 53, 'end_col_offset': 52}
# NO BODY
# children: [<ast.UAdd object at 0x10347fe80>, <ast.Name object at 0x105fdf310>]
#
# <ast.Name object at 0x10614d250>
# {'id': 'chess', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 1, 'col_offset': 15, 'end_lineno': 1, 'end_col_offset': 20}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Attribute object at 0x105b6d070>
# {'value': <ast.Name object at 0x105b6dca0>, 'attr': 'Board', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 3, 'col_offset': 24, 'end_lineno': 3, 'end_col_offset': 35}
# NO BODY
# children: [<ast.Name object at 0x105b6dca0>, <ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x1059ea610>
# {'id': 'bool', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 3, 'col_offset': 45, 'end_lineno': 3, 'end_col_offset': 49}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105cc83a0>
# {'id': 'int', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 3, 'col_offset': 58, 'end_lineno': 3, 'end_col_offset': 61}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105b698b0>
# {'id': 'int', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 3, 'col_offset': 70, 'end_lineno': 3, 'end_col_offset': 73}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105b699d0>
# {'id': 'int', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 3, 'col_offset': 81, 'end_lineno': 3, 'end_col_offset': 84}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Store object at 0x10347f6a0>
# {'parent': <ast.Name object at 0x105fdc070>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105b69790>
# {'id': 'eval_material', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 5, 'col_offset': 12, 'end_lineno': 5, 'end_col_offset': 25}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105b715b0>
# {'id': 'b', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 5, 'col_offset': 26, 'end_lineno': 5, 'end_col_offset': 27}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105b71520>
# {'id': 'player', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 5, 'col_offset': 29, 'end_lineno': 5, 'end_col_offset': 35}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Or object at 0x10347f7f0>
# {'parent': <ast.BoolOp object at 0x105d12ac0>}
# NO BODY
# children: []
#
# <ast.Compare object at 0x105b718b0>
# {'left': <ast.Name object at 0x105b715e0>, 'ops': [<ast.Eq object at 0x10347ff70>], 'comparators': [<ast.Constant object at 0x105b71df0>], 'lineno': 6, 'col_offset': 11, 'end_lineno': 6, 'end_col_offset': 21}
# NO BODY
# children: [<ast.Name object at 0x105b715e0>, <ast.Eq object at 0x10347ff70>, <ast.Constant object at 0x105b71df0>]
#
# <ast.Compare object at 0x105b71d00>
# {'left': <ast.Call object at 0x105b71730>, 'ops': [<ast.Eq object at 0x10347ff70>], 'comparators': [<ast.Name object at 0x105b71dc0>], 'lineno': 6, 'col_offset': 25, 'end_lineno': 6, 'end_col_offset': 38}
# NO BODY
# children: [<ast.Call object at 0x105b71730>, <ast.Eq object at 0x10347ff70>, <ast.Name object at 0x105b71dc0>]
#
# <ast.Tuple object at 0x105b71910>
# {'elts': [<ast.Name object at 0x105b713d0>, <ast.Constant object at 0x105b71970>], 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 7, 'col_offset': 19, 'end_lineno': 7, 'end_col_offset': 26}
# NO BODY
# children: [<ast.Name object at 0x105b713d0>, <ast.Constant object at 0x105b71970>, <ast.Load object at 0x10347f640>]
#
# <ast.Store object at 0x10347f6a0>
# {'parent': <ast.Name object at 0x105fdc070>}
# NO BODY
# children: []
#
# <ast.USub object at 0x10347fee0>
# {'parent': <ast.UnaryOp object at 0x105cc3c70>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105b71790>
# {'id': 'inf', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 9, 'col_offset': 22, 'end_lineno': 9, 'end_col_offset': 25}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Store object at 0x10347f6a0>
# {'parent': <ast.Name object at 0x105fdc070>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Store object at 0x10347f6a0>
# {'parent': <ast.Name object at 0x105fdc070>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105b6bb20>
# {'id': 'b', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 11, 'col_offset': 17, 'end_lineno': 11, 'end_col_offset': 18}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105b6b880>
# {'id': 'temp_board', 'ctx': <ast.Store object at 0x10347f6a0>, 'lineno': 12, 'col_offset': 12, 'end_lineno': 12, 'end_col_offset': 22}
# NO BODY
# children: [<ast.Store object at 0x10347f6a0>]
#
# <ast.Call object at 0x105b6bdc0>
# {'func': <ast.Attribute object at 0x105b6bd90>, 'args': [], 'keywords': [], 'lineno': 12, 'col_offset': 25, 'end_lineno': 12, 'end_col_offset': 33}
# NO BODY
# children: [<ast.Attribute object at 0x105b6bd90>]
#
# <ast.Call object at 0x105b6bf40>
# {'func': <ast.Attribute object at 0x105b6b700>, 'args': [<ast.Name object at 0x105fdc820>], 'keywords': [], 'lineno': 13, 'col_offset': 12, 'end_lineno': 13, 'end_col_offset': 30}
# NO BODY
# children: [<ast.Attribute object at 0x105b6b700>, <ast.Name object at 0x105fdc820>]
#
# <ast.Name object at 0x105fdc280>
# {'id': 'new_value', 'ctx': <ast.Store object at 0x10347f6a0>, 'lineno': 14, 'col_offset': 12, 'end_lineno': 14, 'end_col_offset': 21}
# NO BODY
# children: [<ast.Store object at 0x10347f6a0>]
#
# <ast.Subscript object at 0x105fdcb50>
# {'value': <ast.Call object at 0x105fdc3a0>, 'slice': <ast.Constant object at 0x105fdcd60>, 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 14, 'col_offset': 24, 'end_lineno': 14, 'end_col_offset': 83}
# NO BODY
# children: [<ast.Call object at 0x105fdc3a0>, <ast.Constant object at 0x105fdcd60>, <ast.Load object at 0x10347f640>]
#
# <ast.Compare object at 0x105fdcf70>
# {'left': <ast.Name object at 0x105fdc5b0>, 'ops': [<ast.Gt object at 0x103488130>], 'comparators': [<ast.Name object at 0x105fdca30>], 'lineno': 17, 'col_offset': 15, 'end_lineno': 17, 'end_col_offset': 37}
# NO BODY
# children: [<ast.Name object at 0x105fdc5b0>, <ast.Gt object at 0x103488130>, <ast.Name object at 0x105fdca30>]
#
# <ast.Assign object at 0x105fdc670>
# {'targets': [<ast.Name object at 0x105fdc0a0>], 'value': <ast.Name object at 0x105fd17c0>, 'type_comment': None, 'lineno': 18, 'col_offset': 16, 'end_lineno': 18, 'end_col_offset': 38}
# NO BODY
# children: [<ast.Name object at 0x105fdc0a0>, <ast.Name object at 0x105fd17c0>]
#
# <ast.Assign object at 0x105fd18b0>
# {'targets': [<ast.Name object at 0x105fd1250>], 'value': <ast.List object at 0x105fd1a00>, 'type_comment': None, 'lineno': 19, 'col_offset': 16, 'end_lineno': 19, 'end_col_offset': 32}
# NO BODY
# children: [<ast.Name object at 0x105fd1250>, <ast.List object at 0x105fd1a00>]
#
# <ast.If object at 0x105fd1760>
# {'test': <ast.Compare object at 0x105fd1190>, 'body': [<ast.Expr object at 0x105fd1fa0>], 'orelse': [], 'lineno': 20, 'col_offset': 12, 'end_lineno': 21, 'end_col_offset': 36}
# [<ast.Expr object at 0x105fd1fa0>]
# children: [<ast.Compare object at 0x105fd1190>, <ast.Expr object at 0x105fd1fa0>]
#
# <ast.Compare object at 0x105fd1640>
# {'left': <ast.Name object at 0x105fd1520>, 'ops': [<ast.GtE object at 0x103488190>], 'comparators': [<ast.Name object at 0x105fd12e0>], 'lineno': 24, 'col_offset': 15, 'end_lineno': 24, 'end_col_offset': 33}
# NO BODY
# children: [<ast.Name object at 0x105fd1520>, <ast.GtE object at 0x103488190>, <ast.Name object at 0x105fd12e0>]
#
# <ast.Break object at 0x105fd1dc0>
# {'lineno': 25, 'col_offset': 16, 'end_lineno': 25, 'end_col_offset': 21}
# NO BODY
# children: []
#
# <ast.Name object at 0x105fd1580>
# {'id': 'alpha', 'ctx': <ast.Store object at 0x10347f6a0>, 'lineno': 26, 'col_offset': 12, 'end_lineno': 26, 'end_col_offset': 17}
# NO BODY
# children: [<ast.Store object at 0x10347f6a0>]
#
# <ast.Call object at 0x105fd1ee0>
# {'func': <ast.Name object at 0x105fd1130>, 'args': [<ast.Name object at 0x105fd1850>, <ast.Name object at 0x105fd1340>], 'keywords': [], 'lineno': 26, 'col_offset': 20, 'end_lineno': 26, 'end_col_offset': 42}
# NO BODY
# children: [<ast.Name object at 0x105fd1130>, <ast.Name object at 0x105fd1850>, <ast.Name object at 0x105fd1340>]
#
# <ast.Name object at 0x105fd1e20>
# {'id': 'best_value', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 28, 'col_offset': 15, 'end_lineno': 28, 'end_col_offset': 25}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Call object at 0x105fd11c0>
# {'func': <ast.Attribute object at 0x105fd1310>, 'args': [<ast.Name object at 0x105fd1220>], 'keywords': [], 'lineno': 28, 'col_offset': 27, 'end_lineno': 28, 'end_col_offset': 52}
# NO BODY
# children: [<ast.Attribute object at 0x105fd1310>, <ast.Name object at 0x105fd1220>]
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Attribute object at 0x105fd15b0>
# {'value': <ast.Name object at 0x105fd1160>, 'attr': 'Board', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 30, 'col_offset': 24, 'end_lineno': 30, 'end_col_offset': 35}
# NO BODY
# children: [<ast.Name object at 0x105fd1160>, <ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fd1b50>
# {'id': 'bool', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 30, 'col_offset': 45, 'end_lineno': 30, 'end_col_offset': 49}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fd1910>
# {'id': 'int', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 30, 'col_offset': 58, 'end_lineno': 30, 'end_col_offset': 61}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fd1b20>
# {'id': 'int', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 30, 'col_offset': 70, 'end_lineno': 30, 'end_col_offset': 73}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fd10a0>
# {'id': 'int', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 30, 'col_offset': 81, 'end_lineno': 30, 'end_col_offset': 84}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Store object at 0x10347f6a0>
# {'parent': <ast.Name object at 0x105fdc070>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105fd19d0>
# {'id': 'eval_material', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 32, 'col_offset': 12, 'end_lineno': 32, 'end_col_offset': 25}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fd1af0>
# {'id': 'b', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 32, 'col_offset': 26, 'end_lineno': 32, 'end_col_offset': 27}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fd1c10>
# {'id': 'player', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 32, 'col_offset': 29, 'end_lineno': 32, 'end_col_offset': 35}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Or object at 0x10347f7f0>
# {'parent': <ast.BoolOp object at 0x105d12ac0>}
# NO BODY
# children: []
#
# <ast.Compare object at 0x105fd1c70>
# {'left': <ast.Name object at 0x105fd14c0>, 'ops': [<ast.Eq object at 0x10347ff70>], 'comparators': [<ast.Constant object at 0x105fd17f0>], 'lineno': 33, 'col_offset': 11, 'end_lineno': 33, 'end_col_offset': 21}
# NO BODY
# children: [<ast.Name object at 0x105fd14c0>, <ast.Eq object at 0x10347ff70>, <ast.Constant object at 0x105fd17f0>]
#
# <ast.Compare object at 0x105fd1f10>
# {'left': <ast.Call object at 0x1059e5d90>, 'ops': [<ast.Eq object at 0x10347ff70>], 'comparators': [<ast.Name object at 0x105d07280>], 'lineno': 33, 'col_offset': 25, 'end_lineno': 33, 'end_col_offset': 38}
# NO BODY
# children: [<ast.Call object at 0x1059e5d90>, <ast.Eq object at 0x10347ff70>, <ast.Name object at 0x105d07280>]
#
# <ast.Tuple object at 0x105b7a460>
# {'elts': [<ast.Name object at 0x105b7adf0>, <ast.Constant object at 0x105b7ac70>], 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 34, 'col_offset': 19, 'end_lineno': 34, 'end_col_offset': 26}
# NO BODY
# children: [<ast.Name object at 0x105b7adf0>, <ast.Constant object at 0x105b7ac70>, <ast.Load object at 0x10347f640>]
#
# <ast.Store object at 0x10347f6a0>
# {'parent': <ast.Name object at 0x105fdc070>}
# NO BODY
# children: []
#
# <ast.UAdd object at 0x10347fe80>
# {}
# NO BODY
# children: []
#
# <ast.Name object at 0x105b7acd0>
# {'id': 'inf', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 36, 'col_offset': 23, 'end_lineno': 36, 'end_col_offset': 26}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Store object at 0x10347f6a0>
# {'parent': <ast.Name object at 0x105fdc070>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105b6e100>
# {'id': 'b', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 37, 'col_offset': 17, 'end_lineno': 37, 'end_col_offset': 18}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105b6e2b0>
# {'id': 'temp_board', 'ctx': <ast.Store object at 0x10347f6a0>, 'lineno': 38, 'col_offset': 12, 'end_lineno': 38, 'end_col_offset': 22}
# NO BODY
# children: [<ast.Store object at 0x10347f6a0>]
#
# <ast.Call object at 0x105b91310>
# {'func': <ast.Attribute object at 0x105b910a0>, 'args': [], 'keywords': [], 'lineno': 38, 'col_offset': 25, 'end_lineno': 38, 'end_col_offset': 33}
# NO BODY
# children: [<ast.Attribute object at 0x105b910a0>]
#
# <ast.Call object at 0x105b91400>
# {'func': <ast.Attribute object at 0x105b91460>, 'args': [<ast.Name object at 0x105b91700>], 'keywords': [], 'lineno': 39, 'col_offset': 12, 'end_lineno': 39, 'end_col_offset': 30}
# NO BODY
# children: [<ast.Attribute object at 0x105b91460>, <ast.Name object at 0x105b91700>]
#
# <ast.Name object at 0x105b91670>
# {'id': 'new_value', 'ctx': <ast.Store object at 0x10347f6a0>, 'lineno': 40, 'col_offset': 12, 'end_lineno': 40, 'end_col_offset': 21}
# NO BODY
# children: [<ast.Store object at 0x10347f6a0>]
#
# <ast.Subscript object at 0x105b913a0>
# {'value': <ast.Call object at 0x105b91190>, 'slice': <ast.Constant object at 0x105fdff40>, 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 40, 'col_offset': 24, 'end_lineno': 40, 'end_col_offset': 83}
# NO BODY
# children: [<ast.Call object at 0x105b91190>, <ast.Constant object at 0x105fdff40>, <ast.Load object at 0x10347f640>]
#
# <ast.Compare object at 0x105fdfe80>
# {'left': <ast.Name object at 0x105fdfcd0>, 'ops': [<ast.Lt object at 0x103488070>], 'comparators': [<ast.Name object at 0x105fdf460>], 'lineno': 43, 'col_offset': 15, 'end_lineno': 43, 'end_col_offset': 38}
# NO BODY
# children: [<ast.Name object at 0x105fdfcd0>, <ast.Lt object at 0x103488070>, <ast.Name object at 0x105fdf460>]
#
# <ast.Assign object at 0x105fdf9a0>
# {'targets': [<ast.Name object at 0x105fdf9d0>], 'value': <ast.Name object at 0x105fdf190>, 'type_comment': None, 'lineno': 44, 'col_offset': 16, 'end_lineno': 44, 'end_col_offset': 39}
# NO BODY
# children: [<ast.Name object at 0x105fdf9d0>, <ast.Name object at 0x105fdf190>]
#
# <ast.Compare object at 0x105fdf100>
# {'left': <ast.Name object at 0x105fdf370>, 'ops': [<ast.LtE object at 0x1034880d0>], 'comparators': [<ast.Name object at 0x105fdf2e0>], 'lineno': 47, 'col_offset': 15, 'end_lineno': 47, 'end_col_offset': 35}
# NO BODY
# children: [<ast.Name object at 0x105fdf370>, <ast.LtE object at 0x1034880d0>, <ast.Name object at 0x105fdf2e0>]
#
# <ast.Break object at 0x105fdfaf0>
# {'lineno': 48, 'col_offset': 16, 'end_lineno': 48, 'end_col_offset': 21}
# NO BODY
# children: []
#
# <ast.Name object at 0x105fdf580>
# {'id': 'beta', 'ctx': <ast.Store object at 0x10347f6a0>, 'lineno': 49, 'col_offset': 12, 'end_lineno': 49, 'end_col_offset': 16}
# NO BODY
# children: [<ast.Store object at 0x10347f6a0>]
#
# <ast.Call object at 0x105fdf640>
# {'func': <ast.Name object at 0x105fdf700>, 'args': [<ast.Name object at 0x105fdf7c0>, <ast.Name object at 0x105fdf520>], 'keywords': [], 'lineno': 49, 'col_offset': 19, 'end_lineno': 49, 'end_col_offset': 41}
# NO BODY
# children: [<ast.Name object at 0x105fdf700>, <ast.Name object at 0x105fdf7c0>, <ast.Name object at 0x105fdf520>]
#
# <ast.Name object at 0x105fdff70>
# {'id': 'worst_value', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 51, 'col_offset': 15, 'end_lineno': 51, 'end_col_offset': 26}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Constant object at 0x105fdf610>
# {'value': None, 'kind': None, 'lineno': 51, 'col_offset': 28, 'end_lineno': 51, 'end_col_offset': 32}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.USub object at 0x10347fee0>
# {'parent': <ast.UnaryOp object at 0x105cc3c70>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105fdf8b0>
# {'id': 'inf', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 53, 'col_offset': 43, 'end_lineno': 53, 'end_col_offset': 46}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.UAdd object at 0x10347fe80>
# {}
# NO BODY
# children: []
#
# <ast.Name object at 0x105fdf310>
# {'id': 'inf', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 53, 'col_offset': 49, 'end_lineno': 53, 'end_col_offset': 52}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105b6dca0>
# {'id': 'chess', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 3, 'col_offset': 24, 'end_lineno': 3, 'end_col_offset': 29}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105b715e0>
# {'id': 'depth', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 6, 'col_offset': 11, 'end_lineno': 6, 'end_col_offset': 16}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Eq object at 0x10347ff70>
# {'parent': <ast.Compare object at 0x105cd3070>}
# NO BODY
# children: []
#
# <ast.Constant object at 0x105b71df0>
# {'value': 0, 'kind': None, 'lineno': 6, 'col_offset': 20, 'end_lineno': 6, 'end_col_offset': 21}
# NO BODY
# children: []
#
# <ast.Call object at 0x105b71730>
# {'func': <ast.Name object at 0x105b71940>, 'args': [<ast.Name object at 0x105b71b80>], 'keywords': [], 'lineno': 6, 'col_offset': 25, 'end_lineno': 6, 'end_col_offset': 31}
# NO BODY
# children: [<ast.Name object at 0x105b71940>, <ast.Name object at 0x105b71b80>]
#
# <ast.Eq object at 0x10347ff70>
# {'parent': <ast.Compare object at 0x105cd3070>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105b71dc0>
# {'id': 'inf', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 6, 'col_offset': 35, 'end_lineno': 6, 'end_col_offset': 38}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105b713d0>
# {'id': 'e', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 7, 'col_offset': 19, 'end_lineno': 7, 'end_col_offset': 20}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Constant object at 0x105b71970>
# {'value': None, 'kind': None, 'lineno': 7, 'col_offset': 22, 'end_lineno': 7, 'end_col_offset': 26}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Store object at 0x10347f6a0>
# {'parent': <ast.Name object at 0x105fdc070>}
# NO BODY
# children: []
#
# <ast.Attribute object at 0x105b6bd90>
# {'value': <ast.Name object at 0x105b6b550>, 'attr': 'copy', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 12, 'col_offset': 25, 'end_lineno': 12, 'end_col_offset': 31}
# NO BODY
# children: [<ast.Name object at 0x105b6b550>, <ast.Load object at 0x10347f640>]
#
# <ast.Attribute object at 0x105b6b700>
# {'value': <ast.Name object at 0x105b6b760>, 'attr': 'push', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 13, 'col_offset': 12, 'end_lineno': 13, 'end_col_offset': 27}
# NO BODY
# children: [<ast.Name object at 0x105b6b760>, <ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fdc820>
# {'id': 'm', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 13, 'col_offset': 28, 'end_lineno': 13, 'end_col_offset': 29}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Store object at 0x10347f6a0>
# {'parent': <ast.Name object at 0x105fdc070>}
# NO BODY
# children: []
#
# <ast.Call object at 0x105fdc3a0>
# {'func': <ast.Name object at 0x105fdcb80>, 'args': [<ast.Name object at 0x105fdca90>, <ast.BinOp object at 0x105fdca60>, <ast.Name object at 0x105fdc700>, <ast.Name object at 0x105fdc340>, <ast.Name object at 0x105fdc580>], 'keywords': [], 'lineno': 14, 'col_offset': 24, 'end_lineno': 14, 'end_col_offset': 80}
# NO BODY
# children: [<ast.Name object at 0x105fdcb80>, <ast.Name object at 0x105fdca90>, <ast.BinOp object at 0x105fdca60>, <ast.Name object at 0x105fdc700>, <ast.Name object at 0x105fdc340>, <ast.Name object at 0x105fdc580>]
#
# <ast.Constant object at 0x105fdcd60>
# {'value': 0, 'kind': None, 'lineno': 14, 'col_offset': 81, 'end_lineno': 14, 'end_col_offset': 82}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105fdc5b0>
# {'id': 'new_value', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 17, 'col_offset': 15, 'end_lineno': 17, 'end_col_offset': 24}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Gt object at 0x103488130>
# {'parent': <ast.Compare object at 0x105d69a60>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105fdca30>
# {'id': 'best_value', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 17, 'col_offset': 27, 'end_lineno': 17, 'end_col_offset': 37}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fdc0a0>
# {'id': 'best_value', 'ctx': <ast.Store object at 0x10347f6a0>, 'lineno': 18, 'col_offset': 16, 'end_lineno': 18, 'end_col_offset': 26}
# NO BODY
# children: [<ast.Store object at 0x10347f6a0>]
#
# <ast.Name object at 0x105fd17c0>
# {'id': 'new_value', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 18, 'col_offset': 29, 'end_lineno': 18, 'end_col_offset': 38}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fd1250>
# {'id': 'best_moves', 'ctx': <ast.Store object at 0x10347f6a0>, 'lineno': 19, 'col_offset': 16, 'end_lineno': 19, 'end_col_offset': 26}
# NO BODY
# children: [<ast.Store object at 0x10347f6a0>]
#
# <ast.List object at 0x105fd1a00>
# {'elts': [<ast.Name object at 0x105fd1f70>], 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 19, 'col_offset': 29, 'end_lineno': 19, 'end_col_offset': 32}
# NO BODY
# children: [<ast.Name object at 0x105fd1f70>, <ast.Load object at 0x10347f640>]
#
# <ast.Compare object at 0x105fd1190>
# {'left': <ast.Name object at 0x105fd1f40>, 'ops': [<ast.Eq object at 0x10347ff70>], 'comparators': [<ast.Name object at 0x105fd1b80>], 'lineno': 20, 'col_offset': 17, 'end_lineno': 20, 'end_col_offset': 40}
# NO BODY
# children: [<ast.Name object at 0x105fd1f40>, <ast.Eq object at 0x10347ff70>, <ast.Name object at 0x105fd1b80>]
#
# <ast.Expr object at 0x105fd1fa0>
# ...
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fdf9d0>
# {'id': 'worst_value', 'ctx': <ast.Store object at 0x10347f6a0>, 'lineno': 44, 'col_offset': 16, 'end_lineno': 44, 'end_col_offset': 27}
# NO BODY
# children: [<ast.Store object at 0x10347f6a0>]
#
# <ast.Name object at 0x105fdf190>
# {'id': 'new_value', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 44, 'col_offset': 30, 'end_lineno': 44, 'end_col_offset': 39}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fdf370>
# {'id': 'worst_value', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 47, 'col_offset': 15, 'end_lineno': 47, 'end_col_offset': 26}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.LtE object at 0x1034880d0>
# {}
# NO BODY
# children: []
#
# <ast.Name object at 0x105fdf2e0>
# {'id': 'alpha', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 47, 'col_offset': 30, 'end_lineno': 47, 'end_col_offset': 35}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Store object at 0x10347f6a0>
# {'parent': <ast.Name object at 0x105fdc070>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105fdf700>
# {'id': 'min', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 49, 'col_offset': 19, 'end_lineno': 49, 'end_col_offset': 22}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fdf7c0>
# {'id': 'beta', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 49, 'col_offset': 23, 'end_lineno': 49, 'end_col_offset': 27}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fdf520>
# {'id': 'worst_value', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 49, 'col_offset': 29, 'end_lineno': 49, 'end_col_offset': 40}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105b71940>
# {'id': 'abs', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 6, 'col_offset': 25, 'end_lineno': 6, 'end_col_offset': 28}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105b71b80>
# {'id': 'e', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 6, 'col_offset': 29, 'end_lineno': 6, 'end_col_offset': 30}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105b6b550>
# {'id': 'b', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 12, 'col_offset': 25, 'end_lineno': 12, 'end_col_offset': 26}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105b6b760>
# {'id': 'temp_board', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 13, 'col_offset': 12, 'end_lineno': 13, 'end_col_offset': 22}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105fdcb80>
# {'id': 'get_min_move', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 14, 'col_offset': 24, 'end_lineno': 14, 'end_col_offset': 36}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fdca90>
# {'id': 'temp_board', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 14, 'col_offset': 37, 'end_lineno': 14, 'end_col_offset': 47}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.BinOp object at 0x105fdca60>
# {'left': <ast.Name object at 0x105fdc430>, 'op': <ast.Sub object at 0x10347f8e0>, 'right': <ast.Constant object at 0x105fdcee0>, 'lineno': 14, 'col_offset': 49, 'end_lineno': 14, 'end_col_offset': 58}
# NO BODY
# children: [<ast.Name object at 0x105fdc430>, <ast.Sub object at 0x10347f8e0>, <ast.Constant object at 0x105fdcee0>]
#
# <ast.Name object at 0x105fdc700>
# {'id': 'player', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 14, 'col_offset': 60, 'end_lineno': 14, 'end_col_offset': 66}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fdc340>
# {'id': 'alpha', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 14, 'col_offset': 68, 'end_lineno': 14, 'end_col_offset': 73}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fdc580>
# {'id': 'beta', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 14, 'col_offset': 75, 'end_lineno': 14, 'end_col_offset': 79}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Store object at 0x10347f6a0>
# {'parent': <ast.Name object at 0x105fdc070>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Store object at 0x10347f6a0>
# {'parent': <ast.Name object at 0x105fdc070>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105fd1f70>
# {'id': 'm', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 19, 'col_offset': 30, 'end_lineno': 19, 'end_col_offset': 31}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105fd1f40>
# {'id': 'new_value', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 20, 'col_offset': 17, 'end_lineno': 20, 'end_col_offset': 26}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Eq object at 0x10347ff70>
# {'parent': <ast.Compare object at 0x105cd3070>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105fd1b80>
# {'id': 'best_value', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 20, 'col_offset': 30, 'end_lineno': 20, 'end_col_offset': 40}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Call object at 0x105fd1a90>
# {'func': <ast.Attribute object at 0x105fd1ca0>, 'args': [<ast.Name object at 0x105fd1a60>], 'keywords': [], 'lineno': 21, 'col_offset': 16, 'end_lineno': 21, 'end_col_offset': 36}
# NO BODY
# children: [<ast.Attribute object at 0x105fd1ca0>, <ast.Name object at 0x105fd1a60>]
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105fd19a0>
# {'id': 'random', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 28, 'col_offset': 27, 'end_lineno': 28, 'end_col_offset': 33}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Name object at 0x1059e5dc0>
# {'id': 'abs', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 33, 'col_offset': 25, 'end_lineno': 33, 'end_col_offset': 28}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x1059e5250>
# {'id': 'e', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 33, 'col_offset': 29, 'end_lineno': 33, 'end_col_offset': 30}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105b91340>
# {'id': 'b', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 38, 'col_offset': 25, 'end_lineno': 38, 'end_col_offset': 26}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105b91610>
# {'id': 'temp_board', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 39, 'col_offset': 12, 'end_lineno': 39, 'end_col_offset': 22}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105b91130>
# {'id': 'get_max_move', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 40, 'col_offset': 24, 'end_lineno': 40, 'end_col_offset': 36}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105b915e0>
# {'id': 'temp_board', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 40, 'col_offset': 37, 'end_lineno': 40, 'end_col_offset': 47}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.BinOp object at 0x105fdfb50>
# {'left': <ast.Name object at 0x105fdfdc0>, 'op': <ast.Sub object at 0x10347f8e0>, 'right': <ast.Constant object at 0x105fdf940>, 'lineno': 40, 'col_offset': 49, 'end_lineno': 40, 'end_col_offset': 58}
# NO BODY
# children: [<ast.Name object at 0x105fdfdc0>, <ast.Sub object at 0x10347f8e0>, <ast.Constant object at 0x105fdf940>]
#
# <ast.Name object at 0x105fdf910>
# {'id': 'player', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 40, 'col_offset': 60, 'end_lineno': 40, 'end_col_offset': 66}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fdfd00>
# {'id': 'alpha', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 40, 'col_offset': 68, 'end_lineno': 40, 'end_col_offset': 73}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fdf730>
# {'id': 'beta', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 40, 'col_offset': 75, 'end_lineno': 40, 'end_col_offset': 79}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Store object at 0x10347f6a0>
# {'parent': <ast.Name object at 0x105fdc070>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105fdc430>
# {'id': 'depth', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 14, 'col_offset': 49, 'end_lineno': 14, 'end_col_offset': 54}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Sub object at 0x10347f8e0>
# {'parent': <ast.BinOp object at 0x105cd30d0>}
# NO BODY
# children: []
#
# <ast.Constant object at 0x105fdcee0>
# {'value': 1, 'kind': None, 'lineno': 14, 'col_offset': 57, 'end_lineno': 14, 'end_col_offset': 58}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Attribute object at 0x105fd1ca0>
# {'value': <ast.Name object at 0x105fd1070>, 'attr': 'append', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 21, 'col_offset': 16, 'end_lineno': 21, 'end_col_offset': 33}
# NO BODY
# children: [<ast.Name object at 0x105fd1070>, <ast.Load object at 0x10347f640>]
#
# <ast.Name object at 0x105fd1a60>
# {'id': 'm', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 21, 'col_offset': 34, 'end_lineno': 21, 'end_col_offset': 35}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105fdfdc0>
# {'id': 'depth', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 40, 'col_offset': 49, 'end_lineno': 40, 'end_col_offset': 54}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Sub object at 0x10347f8e0>
# {'parent': <ast.BinOp object at 0x105cd30d0>}
# NO BODY
# children: []
#
# <ast.Constant object at 0x105fdf940>
# {'value': 1, 'kind': None, 'lineno': 40, 'col_offset': 57, 'end_lineno': 40, 'end_col_offset': 58}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Name object at 0x105fd1070>
# {'id': 'best_moves', 'ctx': <ast.Load object at 0x10347f640>, 'lineno': 21, 'col_offset': 16, 'end_lineno': 21, 'end_col_offset': 26}
# NO BODY
# children: [<ast.Load object at 0x10347f640>]
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []
#
# <ast.Load object at 0x10347f640>
# {'parent': <ast.Name object at 0x105fdc760>}
# NO BODY
# children: []

# %%
def get_min_move(b: chess.Board, player: bool, depth: int, alpha: int, beta: int):
    # e = evaluation(b, player)['total_score']
    e = eval_material(b, player)
    if depth == 0 or abs(e) == inf:
        return e, None
    
    worst_value = +inf
    for m in b.legal_moves:
        temp_board = b.copy()
        temp_board.push(m)
        new_value = get_max_move(temp_board, depth - 1, player, alpha, beta)[0]

        # Maintain a running minimum
        if new_value < worst_value:
            worst_value = new_value

        # Alpha-beta pruning        
        if worst_value <= alpha:
            break
        beta = min(beta, worst_value)

    return worst_value, None

code = inspect.getsource(get_min_move)
def first_exploration(code):
    """
    === code === (Reminder)
    def calculate_average(numbers):
        total = 0
        for element in numbers:
            total += element
        average = total / len(numbers)
        print(average)
        return average
    """
    node = ast.parse(code)
    print(node)
    print(node._fields)
    print()
    
    print(node.body)
    function_body_node = node.body[0]
    print(function_body_node)
    print(function_body_node._fields)
    print(function_body_node.body)  # see how this corresponds to a broad, breadth-type stroke across the AST?
    print()

    '''for_node = function_body_node.body[1]
    print(for_node)
    print(for_node._fields)
    print(for_node.body)  # and see how we are now inside the for loop?

    aug_assign_in_for_loop_node = for_node.body[0]
    print(aug_assign_in_for_loop_node)
    print(aug_assign_in_for_loop_node._fields)
    print(aug_assign_in_for_loop_node.target)  # and see now how can't go any deeper? 
    print(aug_assign_in_for_loop_node.op)
    print(aug_assign_in_for_loop_node.value)
    print()'''

    # so if we were to summarize this entire exploration here, we can see the path we took:
    # function definition -> entire function body -> just the for loop -> body of the for loop -> the aug assign node inside it.
    
    # can we check the type of a node here?
    # let's try:
    '''if isinstance(for_node, ast.For):
        print("yes, this works to check type.")
        print()'''

    # great, so could check structure based on that.

    # so if we were to look for a set of rules based on this, how would we do it?
    # store a list of (ast.__) types that we want to check against
    # do an ast walk through the list, matching each type in the list against something...
    # but wait! if we start the walk from the root, we will find more than we are really after. We'll be searching the entire context.

    # so instead, we first find the local context that we're looking for...
    # then we do check the rest.
    # do our ast walk through that local context...
    # will this work? Let's see:

    # for n in ast.walk(for_node): 
    #     print(n)
    #     # print(node.__dict__)
    #     # print("children: " + str([x for x in ast.iter_child_nodes(node)]) + "\n")
    # print()
    
    # for n in ast.walk(aug_assign_in_for_loop_node):
    #     print(n)
    
first_exploration(code)
# Out:
# <ast.Module object at 0x105ef11c0>
# ('body', 'type_ignores')
#
# [<ast.FunctionDef object at 0x105ef16d0>]
# <ast.FunctionDef object at 0x105ef16d0>
# ('name', 'args', 'body', 'decorator_list', 'returns', 'type_comment')
# [<ast.Assign object at 0x105ef1970>, <ast.If object at 0x105ef1af0>, <ast.Assign object at 0x105ef1bb0>, <ast.For object at 0x105ef11f0>, <ast.Return object at 0x105fdf850>]

# %%
def attempt(code):
    """
    In which we will try to confirm the following structural ruleset:
    [for, increment]
    i.e., that the code has a for loop wherein something is incremented
    """
    ruleset = [ast.For, ast.Add]
    root = ast.parse(code)
    
    # here are all the contexts at the highest level inside the source code
    top_level_context_nodes = root.body[0].body
    print(top_level_context_nodes)

    # try to find the correct local context to match the first rule in the ruleset
    top_context_rule = ruleset[0]
    for top_node in top_level_context_nodes:
        print(top_node)
        
        if isinstance(top_node, top_context_rule):
            print(f"entering local context for rule at node {top_node}")
            return check_local_context(top_node, ruleset[1:])

def check_local_context(local_context_node, rules):
    rule_counter = 0
    for node in ast.walk(local_context_node):
        # if node matches structural requirement, then increment rule counter
        if isinstance(node, rules[rule_counter]):
            print(f"matching rule {rules[rule_counter]} on node {node}")
            rule_counter += 1
            if rule_counter >= len(rules):
                return "Structure fully matched!"
        # if not, do nothing

    return (f"Failed to match structure on rule {rules[rule_counter]}")

ans = attempt(code)
print(ans)
# Out:
# [<ast.Assign object at 0x105b89580>, <ast.If object at 0x105b89280>, <ast.Assign object at 0x105b89c70>, <ast.For object at 0x105b890a0>, <ast.Return object at 0x105fcfaf0>]
# <ast.Assign object at 0x105b89580>
# <ast.If object at 0x105b89280>
# <ast.Assign object at 0x105b89c70>
# <ast.For object at 0x105b890a0>
# entering local context for rule at node <ast.For object at 0x105b890a0>
# Failed to match structure on rule <class 'ast.Add'>

# %%
"""
Some older code you might find useful as a reference.
This method uses the 'NodeVisitor' approach to move through the AST, different from the ast walk approach seen above.

These are magic functions, which are called depending on the name.
The 'visit_Call()' function is called on all nodes that are of 'call' type
The 'visit_For()' function is called on all nodes that are of 'for' type
"""
class FunctionCallVisitor(ast.NodeVisitor):
    def visit_Call(self, node):
        if isinstance(node.func, ast.Name) and node.func.id == "print":
            print(f"yup found a line with a print. It is this line: {node.__dict__}")
            args = [arg for arg in node.args if isinstance(arg, ast.Constant)]
            if args:
                print("Detected print statements with string literals:")
                for arg in args:
                    print(arg.s)  # Print the string literal directly
        self.generic_visit(node)

    def visit_For(self, node):
        # if isinstance(node.func, ast.Name) and node.func.id == "print":
        # print(f"args = {node.args}")
        # args = [arg for arg in node.args if isinstance(arg, ast.Constant)]
        # print(f"node.func = {node.func}")
        # args = [arg for arg in node.args if isinstance(arg, ast.For)]
        # if args:

        # class ast.For(target, iter, body, orelse, type_comment)
        # https://docs.python.org/3/library/ast.html > ctrl+f > ast.for

        print("Detected For statement with...")
        print(f"node.target={node.target} \nnode.iter={node.iter} \nnode.body={node.body} \nnode.orelse={node.orelse} \nnode.type_comment={node.type_comment}")

        # Look for initial loop construct node, 
        # then do a simple tree traversal starting at that loop node

def perform_static_analysis(code):
    """
    === code === (Reminder)
    def calculate_average(numbers):
        total = 0
        for element in numbers:
            total += element
        average = total / len(numbers)
        print(average)
        return average
    """
    tree = ast.parse(code)
    visitor = FunctionCallVisitor()
    visitor.visit(tree)

perform_static_analysis(code)
